# %% [markdown]
# <h1>EDA - Titanic</h1>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('../data/train.csv')
test_df = pd.read_csv('../data/test.csv')

# %% [markdown]
# ### Observações Gerais

# %%
#primeira olhada nos dados de treino
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#primeira olhada nos dados de teste
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train_df[train_df.Survived==1].Sex.value_counts().index
# Out:
# Index(['female', 'male'], dtype='object')

# %%
fig = plt.figure(figsize=(22, 5))
ax = fig.add_subplot(1, 2, 1)
ax.pie(train_df.Survived.value_counts(), labels=['Mortos', 'Sobreviventes'], startangle=90, shadow=True, autopct='%1.1f%%')

ax = fig.add_subplot(1, 2, 2)
ax.pie(train_df[train_df.Survived==1].Sex.value_counts(), labels=train_df[train_df.Survived==1].Sex.value_counts().index, startangle=90, shadow=True, autopct='%1.1f%%')

#ax.set_title('Retrato da Tragédia do Naufrágio do Titanic - 1912')
plt.show()

# %% [markdown]
# ### Relação de Mortos por Gênero e Classe Social

# %%
fig = plt.figure(figsize=(18, 4))
sns.catplot(data=df, x='Sex', hue='Pclass', col='Survived', kind='count')
plt.show()

# %%
fig = plt.figure(figsize=(18, 4))
ax = fig.add_subplot(1, 2, 1)
sns.countplot(data=df[df.Survived==0], x='Sex', hue='Pclass', ax=ax)
#ax.set_xticklabels(labels=['Masculino', 'Feminino'])
ax.set_title('Mortos')
ax.set_xlabel('Gênero')
ax.set_ylabel('Qtde')
#ax.legend(['1a', '2a', '3a'])

ax = fig.add_subplot(1, 2, 2)
sns.countplot(data=df[df.Survived==1], x='Sex', hue='Pclass', ax=ax)
#ax.set_xticklabels(labels=['Masculino', 'Feminino'])
ax.set_title('Sobreviventes')
ax.set_xlabel('Gênero')
ax.set_ylabel('Qtde')
#ax.legend(['1a', '2a', '3a'])
# Out:
# Text(0, 0.5, 'Qtde')

# %%
for col in test_df.columns:
    if(train_df[col].nunique()<10):        
        print(col + ': ' + str(train_df[col].unique()))
# Out:
# Pclass: [3 1 2]
# Sex: ['male' 'female']
# SibSp: [1 0 3 4 2 5 8]
# Parch: [0 1 2 5 3 4 6]
# Embarked: ['S' 'C' 'Q' nan]

# %%
pd.crosstab(df[df.Survived==1].Sex, df[df.Survived==1].Pclass)
# Out:
# Pclass   1   2   3
# Sex
# female  91  70  72
# male    45  17  47

# %%
pd.crosstab(df[df.Survived==1].Sex, df[df.Survived==1].SibSp)
# Out:
# SibSp     0   1   2  3  4
# Sex
# female  137  80  10  4  2
# male     73  32   3  0  1

# %%
pd.crosstab(df[df.Survived==1].Sex, df[df.Survived==1].Parch)
# Out:
# Parch     0   1   2  3  5
# Sex
# female  153  46  30  3  1
# male     80  19  10  0  0

# %%
pd.crosstab(df[df.Survived==1].Sex, df[df.Survived==1].Embarked)
# Out:
# Embarked   C   Q    S
# Sex
# female    64  27  140
# male      29   3   77

# %%
fig = plt.figure(figsize=(18, 4))
ax = fig.add_subplot(1, 1, 1)
ax.hist(x=train_df.Age, bins=25)
plt.show()

# %%
fig = plt.figure(figsize=(18, 4))
ax = fig.add_subplot(1, 1, 1)
sns.countplot(data=train_df, x='Pclass', hue='Sex', ax=ax)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.bar(train_df.Pclass.unique(), train_df[train_df.Survived==0].Pclass.value_counts(), label='Mortos')
ax.bar(train_df.Pclass.unique(), train_df[train_df.Survived==1].Pclass.value_counts(), bottom=train_df[train_df.Survived==0].Pclass.value_counts(), label='Sobreviventes')
plt.show()

# %% [markdown]
# ### Qual é o perfil das pessoas que mais sobreviveram ao desastre do Titanic?

# %% [markdown]
# ### Se você tivesse que viajar no Titanic naquela época qual seria sua chance de sobreviver ao desastre?

# %% [markdown]
# ### Com o modelo em mãos o que você faria para maximizar suas chances?
